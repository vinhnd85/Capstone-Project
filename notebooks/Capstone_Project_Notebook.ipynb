# %% [markdown]
# # Capstone Project Notebook
#
# This notebook was created by GitHub Copilot for the repository vinhnd85/Capstone-Project.
#
# Sections:
# - Intro
# - Quick repo inspection

# %%
import os
print('Repository: vinhnd85/Capstone-Project')
print('Current working directory:', os.getcwd())
print('
Top-level files:')
for f in os.listdir('.'):
    print('-', f)
